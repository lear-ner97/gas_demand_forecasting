# %% [markdown]
# references:
#
#
# *   Multivariate Time Series Forecasting with LSTMs in Keras (machinelearningmastery.com)
# *   https://www.youtube.com/watch?v=4FmVIpcwl4k&t=1117s
#
#
# *   BOOK: Hands-on time series analysis
# *   List item

# %%
from numpy.random import seed
seed(1)
import tensorflow as tf
tf.compat.v1.set_random_seed(2)

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from keras.constraints import maxnorm
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import tensorflow as tf
from keras.models import load_model
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import cross_val_score

mpl.rcParams['figure.figsize'] = (20, 20)
mpl.rcParams['axes.grid'] = False

# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.layers import LSTM,Bidirectional

# %%
df = pd.read_csv('/content/clean_monthly_df_human_supervised.csv')

# %%
df.head()
# Out:
#          time  ...  max_pdl_daily_load_t
# 0  28/02/2015  ...                  1494
# 1  31/03/2015  ...                  1551
# 2  30/04/2015  ...                  1253
# 3  31/05/2015  ...                  1123
# 4  30/06/2015  ...                  1122
#
# [5 rows x 13 columns]

# %%
df.tail()
# Out:
#           time  ...  max_pdl_daily_load_t
# 61  31/03/2020  ...                  1463
# 62  30/04/2020  ...                  1599
# 63  31/05/2020  ...                  1400
# 64  30/06/2020  ...                  1105
# 65  31/07/2020  ...                  1084
#
# [5 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   time                            66 non-null     object
#  1   MIN_TEMPERATURE_C_t_1           66 non-null     int64
#  2   max_clients_month_t_1           66 non-null     int64
#  3   total_Holiday_Food_Related_t_1  66 non-null     int64
#  4   total_consommation_t_1          66 non-null     float64
#  5   max_pdl_total_daily_load_t_1    66 non-null     int64
#  6   max_pdl_daily_load_t_1          66 non-null     int64
#  7   MIN_TEMPERATURE_C_t             66 non-null     int64
#  8   max_clients_month_t             66 non-null     int64
#  9   total_Holiday_Food_Related_t    66 non-null     int64
#  10  total_consommation_t            66 non-null     float64
#  11  max_pdl_total_daily_load_t      66 non-null     int64
#  12  max_pdl_daily_load_t            66 non-null     int64
# dtypes: float64(2), int64(10), object(1)
# memory usage: 6.8+ KB

# %%
time = pd.to_datetime(df['time'], dayfirst=True).dropna()

# %%
df.describe()
# Out:
#        MIN_TEMPERATURE_C_t_1  ...  max_pdl_daily_load_t
# count              66.000000  ...             66.000000
# mean               16.833333  ...           1258.833333
# std                 5.682858  ...            201.377150
# min                 8.000000  ...            892.000000
# 25%                12.000000  ...           1096.250000
# 50%                16.000000  ...           1270.000000
# 75%                22.000000  ...           1417.000000
# max                27.000000  ...           1628.000000
#
# [8 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['time', 'MIN_TEMPERATURE_C_t_1', 'max_clients_month_t_1',
#        'total_Holiday_Food_Related_t_1', 'total_consommation_t_1',
#        'max_pdl_total_daily_load_t_1', 'max_pdl_daily_load_t_1',
#        'MIN_TEMPERATURE_C_t', 'max_clients_month_t',
#        'total_Holiday_Food_Related_t', 'total_consommation_t',
#        'max_pdl_total_daily_load_t', 'max_pdl_daily_load_t'],
#       dtype='object')

# %%
df_input=df[['MIN_TEMPERATURE_C_t_1', 'max_clients_month_t_1',
       'total_Holiday_Food_Related_t_1', 'total_consommation_t_1',
       'max_pdl_total_daily_load_t_1', 'max_pdl_daily_load_t_1',
       
       'MIN_TEMPERATURE_C_t', 'max_clients_month_t',
       'total_Holiday_Food_Related_t','max_pdl_daily_load_t']].dropna()

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(df_input)

# %%
data_scaled[-1]
# Out:
# array([0.63157895, 0.97816594, 0.        , 0.23666579, 0.34943489,
#        0.28940217, 0.78947368, 0.94214876, 0.03571429, 0.26086957])

# %%
features=data_scaled[:,:-1]
target=data_scaled[:,-1]

# %%
features.shape
# Out:
# (66, 9)

# %%
target.shape
# Out:
# (66,)

# %%
# split into train and test sets

n_train_days = -7

train_X,train_y = features[:n_train_days, :],target[:n_train_days]
test_X, test_y = features[n_train_days:, :],target[n_train_days:]

# reshape input to be 3D
train_X = train_X.reshape((train_X.shape[0], train_X.shape[1],1))
test_X = test_X.reshape((test_X.shape[0],test_X.shape[1],1))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (59, 9, 1) (59,) (7, 9, 1) (7,)

# %%
def create_model(layers):
    model = Sequential()
    for i, nodes in enumerate(layers):
        if i==0:
            model.add(Bidirectional(LSTM(units=nodes,input_shape= (train_X.shape[1],1),
                                         kernel_constraint=maxnorm(3.5))))
            model.add(Dropout(0.3))
        else:
            model.add(Bidirectional(LSTM(units=nodes, kernel_constraint=maxnorm(3.5))))
            model.add(Dropout(0.3))
    model.add(Dense(1)) 
    
    model.compile(loss='mse', optimizer='adam')
    return model

model = KerasClassifier(build_fn=create_model, verbose=0) #build_fn is the name of the 
#function to call to get your model.   
tscv = TimeSeriesSplit(n_splits=4)
layers = [[100], [100, 50], [100, 50, 25]]
batches=[4,8]
epochs=[100,200]
param_grid = dict(layers=layers, batch_size = batches , epochs=epochs)
gsearch = GridSearchCV(estimator=model, cv=tscv, param_grid=param_grid,scoring='r2')
grid_result=gsearch.fit(train_X, train_y)
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_5 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_7 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (4, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_9 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_11 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (4, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_13 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_16 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (4, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_19 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_22 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (4, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb2e9fec9e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb2cc04ddd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_29 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_31 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (4, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_33 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_35 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (4, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_37 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_40 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (4, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_43 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_46 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (4, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_53 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_55 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (8, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_57 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_59 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_61 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_64 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (8, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_67 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_70 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_77 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_79 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (8, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_81 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_83 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_85 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_88 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (8, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_91 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_94 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# Best: -3.337210 using {'batch_size': 4, 'epochs': 100, 'layers': [100]}

# %%
model = Sequential()
model.add(Bidirectional(LSTM(units=100,input_shape= (train_X.shape[1],1),kernel_constraint=maxnorm(3.5))))
model.add(Dropout(0.3))
model.add(Dense(units=1))

es = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=20,mode='min',verbose=1)
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', verbose=1, 
                     save_best_only=True)
model.compile(loss='mae', optimizer='adam')
history = model.fit(train_X, train_y, epochs=100, batch_size=4,validation_data=(test_X,test_y),
                    verbose=0,callbacks=[es,mc], shuffle=False)
# Out:
# Epoch 00001: val_loss improved from inf to 0.22595, saving model to best_model.h5
#
# Epoch 00002: val_loss did not improve from 0.22595
#
# Epoch 00003: val_loss did not improve from 0.22595
#
# Epoch 00004: val_loss improved from 0.22595 to 0.21902, saving model to best_model.h5
#
# Epoch 00005: val_loss did not improve from 0.21902
#
# Epoch 00006: val_loss did not improve from 0.21902
#
# Epoch 00007: val_loss improved from 0.21902 to 0.20626, saving model to best_model.h5
#
# Epoch 00008: val_loss improved from 0.20626 to 0.20055, saving model to best_model.h5
#
# Epoch 00009: val_loss improved from 0.20055 to 0.17647, saving model to best_model.h5
#
# Epoch 00010: val_loss did not improve from 0.17647
#
# Epoch 00011: val_loss improved from 0.17647 to 0.15465, saving model to best_model.h5
#
# Epoch 00012: val_loss did not improve from 0.15465
#
# Epoch 00013: val_loss improved from 0.15465 to 0.14382, saving model to best_model.h5
#
# Epoch 00014: val_loss did not improve from 0.14382
#
# Epoch 00015: val_loss did not improve from 0.14382
#
# Epoch 00016: val_loss did not improve from 0.14382
#
# Epoch 00017: val_loss did not improve from 0.14382
#
# Epoch 00018: val_loss improved from 0.14382 to 0.14261, saving model to best_model.h5
#
# Epoch 00019: val_loss did not improve from 0.14261
#
# Epoch 00020: val_loss did not improve from 0.14261
#
# Epoch 00021: val_loss improved from 0.14261 to 0.13608, saving model to best_model.h5
#
# Epoch 00022: val_loss improved from 0.13608 to 0.13485, saving model to best_model.h5
#
# Epoch 00023: val_loss improved from 0.13485 to 0.13281, saving model to best_model.h5
#
# Epoch 00024: val_loss did not improve from 0.13281
#
# Epoch 00025: val_loss did not improve from 0.13281
#
# Epoch 00026: val_loss did not improve from 0.13281
#
# Epoch 00027: val_loss did not improve from 0.13281
#
# Epoch 00028: val_loss did not improve from 0.13281
#
# Epoch 00029: val_loss did not improve from 0.13281
#
# Epoch 00030: val_loss did not improve from 0.13281
#
# Epoch 00031: val_loss did not improve from 0.13281
#
# Epoch 00032: val_loss improved from 0.13281 to 0.13242, saving model to best_model.h5
#
# Epoch 00033: val_loss did not improve from 0.13242
#
# Epoch 00034: val_loss did not improve from 0.13242
#
# Epoch 00035: val_loss improved from 0.13242 to 0.12554, saving model to best_model.h5
#
# Epoch 00036: val_loss did not improve from 0.12554
#
# Epoch 00037: val_loss did not improve from 0.12554
#
# Epoch 00038: val_loss did not improve from 0.12554
#
# Epoch 00039: val_loss did not improve from 0.12554
#
# Epoch 00040: val_loss did not improve from 0.12554
#
# Epoch 00041: val_loss did not improve from 0.12554
#
# Epoch 00042: val_loss did not improve from 0.12554
#
# Epoch 00043: val_loss improved from 0.12554 to 0.12509, saving model to best_model.h5
#
# Epoch 00044: val_loss did not improve from 0.12509
#
# Epoch 00045: val_loss did not improve from 0.12509
#
# Epoch 00046: val_loss improved from 0.12509 to 0.11967, saving model to best_model.h5
#
# Epoch 00047: val_loss did not improve from 0.11967
#
# Epoch 00048: val_loss did not improve from 0.11967
#
# Epoch 00049: val_loss improved from 0.11967 to 0.11892, saving model to best_model.h5
#
# Epoch 00050: val_loss did not improve from 0.11892
#
# Epoch 00051: val_loss did not improve from 0.11892
#
# Epoch 00052: val_loss improved from 0.11892 to 0.11760, saving model to best_model.h5
#
# Epoch 00053: val_loss did not improve from 0.11760
#
# Epoch 00054: val_loss did not improve from 0.11760
#
# Epoch 00055: val_loss did not improve from 0.11760
#
# Epoch 00056: val_loss did not improve from 0.11760
#
# Epoch 00057: val_loss did not improve from 0.11760
#
# Epoch 00058: val_loss improved from 0.11760 to 0.11333, saving model to best_model.h5
#
# Epoch 00059: val_loss did not improve from 0.11333
#
# Epoch 00060: val_loss did not improve from 0.11333
#
# Epoch 00061: val_loss did not improve from 0.11333
#
# Epoch 00062: val_loss did not improve from 0.11333
#
# Epoch 00063: val_loss did not improve from 0.11333
#
# Epoch 00064: val_loss did not improve from 0.11333
#
# Epoch 00065: val_loss did not improve from 0.11333
#
# Epoch 00066: val_loss did not improve from 0.11333
#
# Epoch 00067: val_loss improved from 0.11333 to 0.10943, saving model to best_model.h5
#
# Epoch 00068: val_loss did not improve from 0.10943
#
# Epoch 00069: val_loss did not improve from 0.10943
#
# Epoch 00070: val_loss did not improve from 0.10943
#
# Epoch 00071: val_loss did not improve from 0.10943
#
# Epoch 00072: val_loss improved from 0.10943 to 0.10474, saving model to best_model.h5
#
# Epoch 00073: val_loss did not improve from 0.10474
#
# Epoch 00074: val_loss improved from 0.10474 to 0.10266, saving model to best_model.h5
#
# Epoch 00075: val_loss did not improve from 0.10266
#
# Epoch 00076: val_loss did not improve from 0.10266
#
# Epoch 00077: val_loss improved from 0.10266 to 0.09770, saving model to best_model.h5
#
# Epoch 00078: val_loss did not improve from 0.09770
#
# Epoch 00079: val_loss did not improve from 0.09770
#
# Epoch 00080: val_loss did not improve from 0.09770
#
# Epoch 00081: val_loss did not improve from 0.09770
#
# Epoch 00082: val_loss did not improve from 0.09770
#
# Epoch 00083: val_loss did not improve from 0.09770
#
# Epoch 00084: val_loss did not improve from 0.09770
#
# Epoch 00085: val_loss did not improve from 0.09770
#
# Epoch 00086: val_loss did not improve from 0.09770
#
# Epoch 00087: val_loss improved from 0.09770 to 0.06929, saving model to best_model.h5
#
# Epoch 00088: val_loss did not improve from 0.06929
#
# Epoch 00089: val_loss did not improve from 0.06929
#
# Epoch 00090: val_loss did not improve from 0.06929
#
# Epoch 00091: val_loss did not improve from 0.06929
#
# Epoch 00092: val_loss did not improve from 0.06929
#
# Epoch 00093: val_loss did not improve from 0.06929
#
# Epoch 00094: val_loss did not improve from 0.06929
#
# Epoch 00095: val_loss did not improve from 0.06929
#
# Epoch 00096: val_loss did not improve from 0.06929
#
# Epoch 00097: val_loss did not improve from 0.06929
#
# Epoch 00098: val_loss improved from 0.06929 to 0.06249, saving model to best_model.h5
#
# Epoch 00099: val_loss did not improve from 0.06249
#
# Epoch 00100: val_loss did not improve from 0.06249

# %%
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %% [markdown]
# better stability with df_logic

# %%
  # load the saved model
model = load_model('best_model.h5')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 200)               81600
# _________________________________________________________________
# dropout (Dropout)            (None, 200)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# =================================================================
# Total params: 81,801
# Trainable params: 81,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
# make a prediction
yhat = model.predict(test_X) #shape=(14,1)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[1]))
# invert scaling for forecast
#inv_yhat = concatenate((test_X[:, :-1],yhat), axis=1)
inv_yhat = concatenate((test_X,yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,-1]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
#inv_y = concatenate((test_X[:, :-1],test_y), axis=1)
inv_y = concatenate((test_X,test_y), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,-1]

# %%
def timeseries_evaluation_metrics_func(y_true, y_pred):
  def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
  def smape(y_true,y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return 2/y_true.shape[0]*np.sum(np.abs(y_true-y_pred))/np.sum((np.abs(y_true)+np.abs(y_pred)))*100
  def mase(y_true,y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    naive_pred=y_true[1:]
    return 1/y_true.shape[0]*np.sum(np.abs(y_true-y_pred))/np.sum(np.abs(y_true[:len(y_true)-1]-naive_pred))*(y_true.shape[0]-1)
  #def owe(y_true,y_pred):
   # return (mase(y_true,y_pred)+smape(y_true,y_pred))/2

  print('Evaluation metric results:-')
  print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
  print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
  print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
  print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)} %')
  #mape.append(mean_absolute_percentage_error(y_true, y_pred))
  #rmse.append(np.sqrt(metrics.mean_squared_error(y_true, y_pred)))
  print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')
  print('SMAPE is : '+str(smape(y_true,y_pred))+'\n')
  print('MASE is : '+str(mase(y_true,y_pred)))
  return

# %%
from sklearn import metrics
import numpy as np

timeseries_evaluation_metrics_func(inv_y, inv_yhat)
# Out:
# Evaluation metric results:-
# MSE is : 3528.3154441729143
# MAE is : 45.99040494646345
# RMSE is : 59.39962494976643
# MAPE is : 3.5331859839156063 %
# R2 is : 0.9034967754954045
#
# SMAPE is : 0.47211883503719854
#
# MASE is : 0.3574383804129283

# %%
from matplotlib.pyplot import figure

figure(figsize=(8, 6), dpi=80)
plt.plot(time[train_X.shape[0]:len(time)],inv_y,label='actual')
plt.plot(time[train_X.shape[0]:len(time)],inv_yhat,label='Pred')
plt.legend()
#plt.savefig('xgboost_test')
plt.show()

# %% [markdown]
# # peak period

# %%
timeseries_evaluation_metrics_func(inv_y[:3], inv_yhat[:3])
# Out:
# Evaluation metric results:-
# MSE is : 1247.9908855134406
# MAE is : 28.41742515563965
# RMSE is : 35.32691446352824
# MAPE is : 1.947138602687949 %
# R2 is : 0.475976580683915
#
# SMAPE is : 0.6297326040675398
#
# MASE is : 0.46970950670478756

# %%
from matplotlib.pyplot import figure
import matplotlib.dates as mdates
figure(figsize=(8, 6), dpi=80)
plt.plot(time[train_X.shape[0]:train_X.shape[0]+3],inv_y[:3],label='actual')
plt.plot(time[train_X.shape[0]:train_X.shape[0]+3],inv_yhat[:3],label='Pred')
plt.legend()
locator = mdates.MonthLocator()
fmt = mdates.DateFormatter('%b')
X = plt.gca().xaxis
X.set_major_locator(locator)
# Specify formatter
X.set_major_formatter(fmt)
plt.show()
