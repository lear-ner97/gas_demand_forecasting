# %% [markdown]
# references:
#
#
# *   Multivariate Time Series Forecasting with LSTMs in Keras (machinelearningmastery.com)
# *   https://www.youtube.com/watch?v=4FmVIpcwl4k&t=1117s
#
#
# *   BOOK: Hands-on time series analysis
# *   List item

# %%
from numpy.random import seed
seed(1)
import tensorflow as tf
tf.compat.v1.set_random_seed(2)

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from keras.constraints import maxnorm
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import tensorflow as tf
from keras.models import load_model
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import cross_val_score

mpl.rcParams['figure.figsize'] = (20, 20)
mpl.rcParams['axes.grid'] = False

# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.layers import LSTM,Bidirectional

# %%
df = pd.read_csv('/content/clean_daily_df_human_logic_supervised.csv')

# %%
df.head()
# Out:
#          time  MIN_TEMPERATURE_C_t_7  ...  weekend_t  max_pdl_daily_load_t
# 0  08/01/2015                      8  ...          0                1379.0
# 1  09/01/2015                     12  ...          0                1370.0
# 2  10/01/2015                     12  ...          1                1181.0
# 3  11/01/2015                     15  ...          1                1093.0
# 4  12/01/2015                     15  ...          0                1205.0
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#             time  MIN_TEMPERATURE_C_t_7  ...  weekend_t  max_pdl_daily_load_t
# 2027  27/07/2020                     24  ...          0                1010.0
# 2028  28/07/2020                     25  ...          0                 986.0
# 2029  29/07/2020                     25  ...          0                 873.0
# 2030  30/07/2020                     26  ...          0                 762.0
# 2031  31/07/2020                     27  ...          0                 528.0
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2032 entries, 0 to 2031
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   time                      2032 non-null   object
#  1   MIN_TEMPERATURE_C_t_7     2032 non-null   int64
#  2   clients_day_t_7           2032 non-null   int64
#  3   Holiday_Food_Related_t_7  2032 non-null   int64
#  4   consommation_t_7          2032 non-null   float64
#  5   pdl_total_daily_load_t_7  2032 non-null   int64
#  6   max_pdl_daily_load_t_7    2032 non-null   float64
#  7   weekend_t_7               2032 non-null   int64
#  8   MIN_TEMPERATURE_C_t_1     2032 non-null   int64
#  9   clients_day_t_1           2032 non-null   int64
#  10  Holiday_Food_Related_t_1  2032 non-null   int64
#  11  consommation_t_1          2032 non-null   float64
#  12  pdl_total_daily_load_t_1  2032 non-null   int64
#  13  max_pdl_daily_load_t_1    2032 non-null   float64
#  14  weekend_t_1               2032 non-null   int64
#  15  MIN_TEMPERATURE_C_t       2032 non-null   int64
#  16  clients_day_t             2032 non-null   int64
#  17  Holiday_Food_Related_t    2032 non-null   int64
#  18  consommation_t            2032 non-null   float64
#  19  pdl_total_daily_load_t    2032 non-null   int64
#  20  weekend_t                 2032 non-null   int64
#  21  max_pdl_daily_load_t      2032 non-null   float64
# dtypes: float64(6), int64(15), object(1)
# memory usage: 349.4+ KB

# %%
time = pd.to_datetime(df['time'], dayfirst=True).dropna()

# %%
df.describe()
# Out:
#        MIN_TEMPERATURE_C_t_7  ...  max_pdl_daily_load_t
# count            2032.000000  ...           2032.000000
# mean               20.633366  ...           1080.639365
# std                 5.917364  ...            209.429624
# min                 8.000000  ...            404.000000
# 25%                16.000000  ...            935.000000
# 50%                20.000000  ...           1071.000000
# 75%                26.000000  ...           1242.250000
# max                34.000000  ...           1628.000000
#
# [8 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['time', 'MIN_TEMPERATURE_C_t_7', 'clients_day_t_7',
#        'Holiday_Food_Related_t_7', 'consommation_t_7',
#        'pdl_total_daily_load_t_7', 'max_pdl_daily_load_t_7', 'weekend_t_7',
#        'MIN_TEMPERATURE_C_t_1', 'clients_day_t_1', 'Holiday_Food_Related_t_1',
#        'consommation_t_1', 'pdl_total_daily_load_t_1',
#        'max_pdl_daily_load_t_1', 'weekend_t_1', 'MIN_TEMPERATURE_C_t',
#        'clients_day_t', 'Holiday_Food_Related_t', 'consommation_t',
#        'pdl_total_daily_load_t', 'weekend_t', 'max_pdl_daily_load_t'],
#       dtype='object')

# %%
df_input=df[['MIN_TEMPERATURE_C_t_7',
        'clients_day_t_7','Holiday_Food_Related_t_7', 'consommation_t_7',
       'pdl_total_daily_load_t_7', 'max_pdl_daily_load_t_7', 'weekend_t_7',

       'MIN_TEMPERATURE_C_t_1', 'clients_day_t_1', 'Holiday_Food_Related_t_1',
       'consommation_t_1', 'pdl_total_daily_load_t_1',
       'max_pdl_daily_load_t_1', 'weekend_t_1',
       
        'MIN_TEMPERATURE_C_t','clients_day_t', 'Holiday_Food_Related_t',
        'weekend_t', 'max_pdl_daily_load_t']].dropna()

# %% [markdown]
# the add of weekend feature makes the seasonal weekend decrease more visible, so increases performance

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(df_input)

# %%
data_scaled[-1]
# Out:
# array([0.73076923, 0.88078035, 0.        , 0.17276642, 0.4053923 ,
#        0.50081699, 0.        , 0.73076923, 0.88060781, 0.        ,
#        0.17276642, 0.3398278 , 0.29248366, 0.        , 0.76923077,
#        0.88060781, 1.        , 0.        , 0.10130719])

# %%
features=data_scaled[:,:-1]
target=data_scaled[:,-1]

# %%
features.shape
# Out:
# (2032, 18)

# %%
target.shape
# Out:
# (2032,)

# %%
# split into train and test sets

n_train_days = -30*7

train_X,train_y = features[:n_train_days, :],target[:n_train_days]
test_X, test_y = features[n_train_days:, :],target[n_train_days:]

# reshape input to be 3D
train_X = train_X.reshape((train_X.shape[0], train_X.shape[1],1))
test_X = test_X.reshape((test_X.shape[0],test_X.shape[1],1))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (1822, 18, 1) (1822,) (210, 18, 1) (210,)

# %%
def create_model(layers):
    model = Sequential()
    for i, nodes in enumerate(layers):
        if i==0:
            model.add(Bidirectional(LSTM(units=nodes,input_shape= (train_X.shape[1],1),
                                         kernel_constraint=maxnorm(3.5))))
            model.add(Dropout(0.3))
        else:
            model.add(Bidirectional(LSTM(units=nodes, kernel_constraint=maxnorm(3.5))))
            model.add(Dropout(0.3))
    model.add(Dense(1)) 
    
    model.compile(loss='mse', optimizer='adam')
    return model

model = KerasClassifier(build_fn=create_model, verbose=0) #build_fn is the name of the 
#function to call to get your model.   
tscv = TimeSeriesSplit(n_splits=4)
layers = [[100], [100, 50], [100, 50, 25]]
batches=[16,32]
epochs=[100,200]
param_grid = dict(layers=layers, batch_size = batches , epochs=epochs)
gsearch = GridSearchCV(estimator=model, cv=tscv, param_grid=param_grid,scoring='r2')
grid_result=gsearch.fit(train_X, train_y)
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_5 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_7 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_9 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_11 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_13 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_16 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_19 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_22 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_29 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_31 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_33 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_35 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_37 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_40 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_43 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_46 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_53 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_55 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_57 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_59 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_61 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_64 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_67 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_70 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_77 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_79 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_81 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_83 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_85 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_88 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_91 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:389 call  *
#         outputs = layer(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/layers/wrappers.py:581 __call__  *
#         return super(Bidirectional, self).__call__(inputs, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:212 assert_input_compatibility  *
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer bidirectional_94 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 200)
#
#
#   FitFailedWarning)
# Best: -9.754916 using {'batch_size': 16, 'epochs': 100, 'layers': [100]}

# %%
model = Sequential()
model.add(Bidirectional(LSTM(units=100,input_shape= (train_X.shape[1],1))))
model.add(Dropout(0.3))
model.add(Dense(units=1))

es = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=20,mode='min',verbose=1)
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', verbose=1, 
                     save_best_only=True)
model.compile(loss='mae', optimizer='adam')
history = model.fit(train_X, train_y, epochs=100, batch_size=16,validation_data=(test_X,test_y),
                    verbose=0,callbacks=[es,mc], shuffle=False)
# Out:
# Epoch 00001: val_loss improved from inf to 0.16841, saving model to best_model.h5
#
# Epoch 00002: val_loss improved from 0.16841 to 0.14742, saving model to best_model.h5
#
# Epoch 00003: val_loss improved from 0.14742 to 0.14200, saving model to best_model.h5
#
# Epoch 00004: val_loss improved from 0.14200 to 0.11482, saving model to best_model.h5
#
# Epoch 00005: val_loss improved from 0.11482 to 0.09796, saving model to best_model.h5
#
# Epoch 00006: val_loss did not improve from 0.09796
#
# Epoch 00007: val_loss did not improve from 0.09796
#
# Epoch 00008: val_loss did not improve from 0.09796
#
# Epoch 00009: val_loss did not improve from 0.09796
#
# Epoch 00010: val_loss improved from 0.09796 to 0.08866, saving model to best_model.h5
#
# Epoch 00011: val_loss did not improve from 0.08866
#
# Epoch 00012: val_loss did not improve from 0.08866
#
# Epoch 00013: val_loss did not improve from 0.08866
#
# Epoch 00014: val_loss improved from 0.08866 to 0.08507, saving model to best_model.h5
#
# Epoch 00015: val_loss did not improve from 0.08507
#
# Epoch 00016: val_loss did not improve from 0.08507
#
# Epoch 00017: val_loss improved from 0.08507 to 0.08181, saving model to best_model.h5
#
# Epoch 00018: val_loss did not improve from 0.08181
#
# Epoch 00019: val_loss improved from 0.08181 to 0.08065, saving model to best_model.h5
#
# Epoch 00020: val_loss did not improve from 0.08065
#
# Epoch 00021: val_loss did not improve from 0.08065
#
# Epoch 00022: val_loss improved from 0.08065 to 0.07902, saving model to best_model.h5
#
# Epoch 00023: val_loss improved from 0.07902 to 0.07228, saving model to best_model.h5
#
# Epoch 00024: val_loss did not improve from 0.07228
#
# Epoch 00025: val_loss did not improve from 0.07228
#
# Epoch 00026: val_loss improved from 0.07228 to 0.07046, saving model to best_model.h5
#
# Epoch 00027: val_loss improved from 0.07046 to 0.06608, saving model to best_model.h5
#
# Epoch 00028: val_loss improved from 0.06608 to 0.06564, saving model to best_model.h5
#
# Epoch 00029: val_loss did not improve from 0.06564
#
# Epoch 00030: val_loss did not improve from 0.06564
#
# Epoch 00031: val_loss did not improve from 0.06564
#
# Epoch 00032: val_loss did not improve from 0.06564
#
# Epoch 00033: val_loss improved from 0.06564 to 0.06344, saving model to best_model.h5
#
# Epoch 00034: val_loss improved from 0.06344 to 0.05799, saving model to best_model.h5
#
# Epoch 00035: val_loss did not improve from 0.05799
#
# Epoch 00036: val_loss did not improve from 0.05799
#
# Epoch 00037: val_loss did not improve from 0.05799
#
# Epoch 00038: val_loss did not improve from 0.05799
#
# Epoch 00039: val_loss did not improve from 0.05799
#
# Epoch 00040: val_loss did not improve from 0.05799
#
# Epoch 00041: val_loss did not improve from 0.05799
#
# Epoch 00042: val_loss did not improve from 0.05799
#
# Epoch 00043: val_loss did not improve from 0.05799
#
# Epoch 00044: val_loss improved from 0.05799 to 0.05726, saving model to best_model.h5
#
# Epoch 00045: val_loss did not improve from 0.05726
#
# Epoch 00046: val_loss did not improve from 0.05726
#
# Epoch 00047: val_loss did not improve from 0.05726
#
# Epoch 00048: val_loss did not improve from 0.05726
#
# Epoch 00049: val_loss did not improve from 0.05726
#
# Epoch 00050: val_loss did not improve from 0.05726
#
# Epoch 00051: val_loss did not improve from 0.05726
#
# Epoch 00052: val_loss did not improve from 0.05726
#
# Epoch 00053: val_loss did not improve from 0.05726
#
# Epoch 00054: val_loss did not improve from 0.05726
#
# Epoch 00055: val_loss did not improve from 0.05726
#
# Epoch 00056: val_loss did not improve from 0.05726
#
# Epoch 00057: val_loss did not improve from 0.05726
#
# Epoch 00058: val_loss did not improve from 0.05726
#
# Epoch 00059: val_loss did not improve from 0.05726
#
# Epoch 00060: val_loss did not improve from 0.05726
#
# Epoch 00061: val_loss did not improve from 0.05726
#
# Epoch 00062: val_loss did not improve from 0.05726
#
# Epoch 00063: val_loss did not improve from 0.05726
#
# Epoch 00064: val_loss did not improve from 0.05726
# Epoch 00064: early stopping

# %%
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %% [markdown]
# better stability with df_logic

# %%
  # load the saved model
model = load_model('best_model.h5')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 200)               81600
# _________________________________________________________________
# dropout (Dropout)            (None, 200)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# =================================================================
# Total params: 81,801
# Trainable params: 81,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
# make a prediction
yhat = model.predict(test_X) #shape=(14,1)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[1]))
# invert scaling for forecast
#inv_yhat = concatenate((test_X[:, :-1],yhat), axis=1)
inv_yhat = concatenate((test_X,yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,-1]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
#inv_y = concatenate((test_X[:, :-1],test_y), axis=1)
inv_y = concatenate((test_X,test_y), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,-1]

# %%
def timeseries_evaluation_metrics_func(y_true, y_pred):
  def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
  def smape(y_true,y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return 2/y_true.shape[0]*np.sum(np.abs(y_true-y_pred))/np.sum((np.abs(y_true)+np.abs(y_pred)))*100
  def mase(y_true,y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    naive_pred=y_true[1:]
    return 1/y_true.shape[0]*np.sum(np.abs(y_true-y_pred))/np.sum(np.abs(y_true[:len(y_true)-1]-naive_pred))*(y_true.shape[0]-1)
  #def owe(y_true,y_pred):
   # return (mase(y_true,y_pred)+smape(y_true,y_pred))/2

  print('Evaluation metric results:-')
  print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
  print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
  print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
  print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)} %')
  #mape.append(mean_absolute_percentage_error(y_true, y_pred))
  #rmse.append(np.sqrt(metrics.mean_squared_error(y_true, y_pred)))
  print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')
  print('SMAPE is : '+str(smape(y_true,y_pred))+'\n')
  print('MASE is : '+str(mase(y_true,y_pred)))
  return

# %%
from sklearn import metrics
import numpy as np

timeseries_evaluation_metrics_func(inv_y, inv_yhat)
# Out:
# Evaluation metric results:-
# MSE is : 10910.490366684702
# MAE is : 70.09039416653769
# RMSE is : 104.45329275175916
# MAPE is : 6.591499943222379 %
# R2 is : 0.7192013341129104
#
# SMAPE is : 0.027731674065364195
#
# MASE is : 0.8037801031992527

# %%
from matplotlib.pyplot import figure

figure(figsize=(8, 6), dpi=80)
plt.plot(time[train_X.shape[0]:len(time)],inv_y,label='actual')
plt.plot(time[train_X.shape[0]:len(time)],inv_yhat,label='Pred')
plt.legend()
#plt.savefig('xgboost_test')
plt.show()

# %% [markdown]
# # peak period

# %%
timeseries_evaluation_metrics_func(inv_y[:90], inv_yhat[:90])
# Out:
# Evaluation metric results:-
# MSE is : 10169.996740088805
# MAE is : 70.62585487895542
# RMSE is : 100.84640172107682
# MAPE is : 5.6264433016445645 %
# R2 is : 0.39118358883188875
#
# SMAPE is : 0.05922127037615825
#
# MASE is : 0.7054658904856375

# %%
from matplotlib.pyplot import figure

figure(figsize=(8, 6), dpi=80)
plt.plot(time[train_X.shape[0]:train_X.shape[0]+90],inv_y[:90],label='actual')
plt.plot(time[train_X.shape[0]:train_X.shape[0]+90],inv_yhat[:90],label='Pred')
plt.legend()
plt.show()
